# %% [markdown]
# # **NOTE THAT THE 21 PAGES ARE DOWLODED MANUALLY!**

# %%
pip install -U requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\programdata\miniconda3\envs\py\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\miniconda3\envs\py\lib\site-packages (4.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\miniconda3\envs\py\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\envs\py\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniconda3\envs\py\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\py\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\programdata\miniconda3\envs\py\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\programdata\miniconda3\envs\py\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from importlib.metadata import files
import requests
from bs4 import BeautifulSoup
import json
import time
import random
import os
import re
import pandas as pd

# Base URL for the species guide
BASE_URL = "https://app.birda.org/species-guide"
# The TwicPics base domain used for Birda images
TWIC_BASE = "https://birda.twic.pics/"

def get_headers():
    """Returns headers to mimic a real browser."""
    return {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "image/avif,image/webp,image/apng,image/svg+xml,image/*,*/*;q=0.8",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://app.birda.org/",
    }

def extract_birds_from_html(html_content):
    """Parses HTML and extracts bird details including image paths."""
    soup = BeautifulSoup(html_content, 'html.parser')
    birds = []
    
    bird_cards = soup.find_all('a', href=lambda x: x and '/species-guide/' in x)
    
    for card in bird_cards:
        try:
            name_tag = card.find('h4')
            if not name_tag: continue
            common_name = name_tag.get_text(strip=True)
            
            sci_tag = card.find('div', class_='css-xnfnhl')
            scientific_name = sci_tag.get_text(strip=True) if sci_tag else "Unknown"
            
            img_tag = card.find('img')
            raw_path = "N/A"
            
            if img_tag:
                # 'data-twic-src' contains the internal media path
                # e.g., 'media:species/9a2db496.../Acacia_Pied_Barbet.jpg'
                twic_data = img_tag.get('data-twic-src')
                if twic_data and twic_data.startswith('media:'):
                    # Convert 'media:xyz' to 'https://birda.twic.pics/xyz'
                    raw_path = twic_data.replace('media:', TWIC_BASE)
            
            guide_path = card.get('href')
            
            birds.append({
                "common_name": common_name,
                "scientific_name": scientific_name,
                "image_url": raw_path,
                "guide_url": f"{guide_path}"
            })
        except Exception:
            continue
            
    return birds

def download_bird_images(bird_list, folder="bird_images"):
    """Downloads images from the image_url for each bird in the list."""
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    session = requests.Session()
    session.headers.update(get_headers())
    
    for bird in bird_list:
        url = bird['image_url']
        if url == "N/A":
            continue
            
        # Clean filename: replace spaces/special chars with underscores
        safe_name = re.sub(r'[^\w\s-]', '', bird['common_name']).strip().replace(' ', '_')
        file_path = os.path.join(folder, f"{safe_name}.jpg")
        
        if os.path.exists(file_path):
            print(f"Skipping {bird['common_name']}, already exists.")
            continue
            
        try:
            print(f"Downloading {bird['common_name']}...")
            # Append a resize parameter to ensure we get a high-quality version
            # TwicPics syntax: ?twic=v1/resize=1000
            download_url = f"{url}?twic=v1/resize=1200"
            
            response = session.get(download_url, timeout=20)
            if response.status_code == 200:
                with open(file_path, 'wb') as f:
                    f.write(response.content)
                time.sleep(random.uniform(1, 2)) # Small delay between downloads
            else:
                print(f"Failed to download {bird['common_name']} (Status: {response.status_code})")
        except Exception as e:
            print(f"Error downloading {bird['common_name']}: {e}")

if __name__ == "__main__":

    # List of local HTML files to process 
    pages = [file for file in os.listdir('C:\\Users\\scuba\\Downloads\\BIRD APP\\bird-trainer\\2 ALL BIRD DATA\\BIRDA\\BIRDA PAGES') if file.endswith('.html')] 
    
    birds = []
    # Get the directory where the script itself is located
    script_dir = "C:\\Users\\scuba\\Downloads\\BIRD APP\\bird-trainer\\2 ALL BIRD DATA\\BIRDA\\BIRDA PAGES\\"

    for n in range(1, len(pages)+2):
        page = f"page_{n}.html"
        # Join the script directory with the filename
        new_page = os.path.join(script_dir, page)
        # print(os.path.exists(new_page))
        if os.path.exists(new_page):
            print(f"Processing {page}...")
            with open(new_page, 'r', encoding='utf-8') as f:
                birds.extend(extract_birds_from_html(f.read()))
                print(f"Extracted data from {page}")      
    # 2. Save JSON data
    if birds:
        with open("birds_data.json", "w", encoding="utf-8") as f:
            json.dump(birds, f, indent=4)
        print(f"Saved data for {len(birds)} birds to birds_data.json")
        
        # 3. Download the images
        # Warning: This will start downloading files to your environment
    #     download_bird_images(birds)
    # else:
    #     print("No birds found to process.")
# Out:
# c:\ProgramData\miniconda3\envs\py\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Processing page_1.html...
# Extracted data from page_1.html
# Processing page_2.html...
# Extracted data from page_2.html
# Processing page_3.html...
# Extracted data from page_3.html
# Processing page_4.html...
# Extracted data from page_4.html
# Processing page_5.html...
# Extracted data from page_5.html
# Processing page_6.html...
# Extracted data from page_6.html
# Processing page_7.html...
# Extracted data from page_7.html
# Processing page_8.html...
# Extracted data from page_8.html
# Processing page_9.html...
# Extracted data from page_9.html
# Processing page_10.html...
# Extracted data from page_10.html
# Processing page_11.html...
# Extracted data from page_11.html
# Processing page_12.html...
# Extracted data from page_12.html
# Processing page_13.html...
# Extracted data from page_13.html
# Processing page_14.html...
# Extracted data from page_14.html
# Processing page_15.html...
# Extracted data from page_15.html
# Processing page_16.html...
# Extracted data from page_16.html
# Processing page_17.html...
# Extracted data from page_17.html
# Processing page_18.html...
# Extracted data from page_18.html
# Processing page_19.html...
# Extracted data from page_19.html
# Processing page_20.html...
# Extracted data from page_20.html
# Processing page_21.html...
# Extracted data from page_21.html
# Saved data for 993 birds to birds_data.json

# %%
len(birds)
# Out:
# 993

# %%
birds[0]
# Out:
# {'common_name': 'Acacia Pied Barbet',
#  'scientific_name': 'Tricholaema leucomelas',
#  'image_url': 'https://birda.twic.pics/species/9a2db496-7033-439a-8333-4ef05d269a46/reference_images/Acacia_Pied_Barbet.jpg',
#  'guide_url': 'https://app.birda.org/species-guide/11404/Acacia_Pied_Barbet'}

# %% [markdown]
# ## **NOTE THAT SOME BIRD_IMAGES ARE MISSING!**

# %%
df = pd.DataFrame()
for bird in birds:
        # print(bird['common_name'], bird['scientific_name'],bird['image_url'])
        row = bird['common_name'], bird['scientific_name'], bird['image_url']
        df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)
df.columns = ['name', 'scientific', 'image']
df
# Out:
#                             name                  scientific  \
# 0             Acacia Pied Barbet      Tricholaema leucomelas
# 1          Black-collared Barbet            Lybius torquatus
# 2                 Crested Barbet     Trachyphonus vaillantii
# 3                   Green Barbet        Stactolaema olivacea
# 4               Green Tinkerbird          Pogoniulus simplex
# ..                           ...                         ...
# 988    Little Spotted Woodpecker      Campethera cailliautii
# 989             Olive Woodpecker  Dendropicos griseocephalus
# 990         Red-throated Wryneck             Jynx ruficollis
# 991  Speckle-throated Woodpecker   Campethera scriptoricauda
# 992     Livingstone's Flycatcher  Erythrocercus livingstonei
#
#                                                  image
# 0    https://birda.twic.pics/species/9a2db496-7033-...
# 1    https://birda.twic.pics/species/ecd51f7d-78f8-...
# 2    https://birda.twic.pics/species/40bffa5c-f735-...
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 988                                                N/A
# 989  https://birda.twic.pics/species/fe103628-67ff-...
# 990  https://birda.twic.pics/species/8f928302-b1e6-...
# 991                                                N/A
# 992                                                N/A
#
# [993 rows x 3 columns]

# %%
len(df)
# Out:
# 993

# %%
df.to_csv("birda_birdlist (+images).csv", index=False)

# %% [markdown]
# # SCRATCH

# %%
birds
# Out:
# [{'common_name': 'Acacia Pied Barbet',
#   'scientific_name': 'Tricholaema leucomelas',
#   'image_url': 'https://birda.twic.pics/species/9a2db496-7033-439a-8333-4ef05d269a46/reference_images/Acacia_Pied_Barbet.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11404/Acacia_Pied_Barbet'},
#  {'common_name': 'Black-collared Barbet',
#   'scientific_name': 'Lybius torquatus',
#   'image_url': 'https://birda.twic.pics/species/ecd51f7d-78f8-4246-b1e4-7359b13ab704/reference_images/Black-collared_Barbet_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11447/Black-collared_Barbet'},
#  {'common_name': 'Crested Barbet',
#   'scientific_name': 'Trachyphonus vaillantii',
#   'image_url': 'https://birda.twic.pics/species/40bffa5c-f735-4d85-add0-6cee03396e6f/reference_images/Crested_Barbet_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11479/Crested_Barbet'},
#  {'common_name': 'Green Barbet',
#   'scientific_name': 'Stactolaema olivacea',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/11333/Green_Barbet'},
#  {'common_name': 'Green Tinkerbird',
#   'scientific_name': 'Pogoniulus simplex',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/11345/Green_Tinkerbird'},
#  {'common_name': 'Red-fronted Tinkerbird',
#   'scientific_name': 'Pogoniulus pusillus',
#   'image_url': 'https://birda.twic.pics/species/ac2b94a5-7c51-4b34-9562-a01fa91b2859/reference_images/Red-fronted_Tinkerbird.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11372/Red-fronted_Tinkerbird'},
#  {'common_name': 'White-eared Barbet',
#   'scientific_name': 'Stactolaema leucotis',
#   'image_url': 'https://birda.twic.pics/species/bf82b33d-babe-4117-8697-f9f4d0b10a7f/reference_images/White-eared_Barbet.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11316/White-eared_Barbet'},
#  {'common_name': "Whyte's Barbet",
#   'scientific_name': 'Stactolaema whytii',
#   'image_url': 'N/A',
#   'guide_url': "https://app.birda.org/species-guide/11322/Whyte's_Barbet"},
#  {'common_name': 'Yellow-fronted Tinkerbird',
#   'scientific_name': 'Pogoniulus chrysoconus',
#   'image_url': 'https://birda.twic.pics/species/28f9ac00-80c9-4174-818e-e1f31966fc97/reference_images/Yellow-fronted_Tinkerbird.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11377/Yellow-fronted_Tinkerbird'},
#  {'common_name': 'Yellow-rumped Tinkerbird',
#   'scientific_name': 'Pogoniulus bilineatus',
#   'image_url': 'https://birda.twic.pics/species/6a38b1fe-f6d7-48db-bce4-48bac005a92f/reference_images/Yellow-rumped_Tinkerbird_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/11359/Yellow-rumped_Tinkerbird'},
#  {'common_name': 'African Broadbill',
#   'scientific_name': 'Smithornis capensis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/14156/African_Broadbill'},
#  {'common_name': 'Brown-headed Parrot',
#   'scientific_name': 'Poicephalus cryptoxanthus',
#   'image_url': 'https://birda.twic.pics/species/72f3f357-6f21-4270-992b-35596c31a87d/reference_images/Brown-headed_Parrot.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/13005/Brown-headed_Parrot'},
#  {'common_name': 'Brown-necked Parrot',
#   'scientific_name': 'Poicephalus fuscicollis',
#   'image_url': 'https://birda.twic.pics/species/617456a5-97d3-4f67-bea7-8615b76cd92b/reference_images/Brown-necked_Parrot-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12989/Brown-necked_Parrot'},
#  {'common_name': 'Cape Parrot',
#   'scientific_name': 'Poicephalus robustus',
#   'image_url': 'https://birda.twic.pics/species/de238770-cc7e-406c-8db3-bf07370e5d08/reference_images/Cape_Parrot-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12993/Cape_Parrot'},
#  {'common_name': "Meyer's Parrot",
#   'scientific_name': 'Poicephalus meyeri',
#   'image_url': 'https://birda.twic.pics/species/53ef0d59-ca1e-4103-9edd-a99239d108d4/reference_images/Meyers_Parrot.jpg',
#   'guide_url': "https://app.birda.org/species-guide/12995/Meyer's_Parrot"},
#  {'common_name': "Rüppell's Parrot",
#   'scientific_name': 'Poicephalus rueppellii',
#   'image_url': 'https://birda.twic.pics/species/4a486550-c645-431b-b17d-f5c171e70650/reference_images/Ruppells_Parrot-_Male_1.jpg',
#   'guide_url': "https://app.birda.org/species-guide/13004/R%C3%BCppell's_Parrot"},
#  {'common_name': 'Amsterdam Albatross',
#   'scientific_name': 'Diomedea amsterdamensis',
#   'image_url': 'https://birda.twic.pics/species/d1ea3464-991a-4c42-82d3-c5d8e00164e8/reference_images/Amsterdam_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7336/Amsterdam_Albatross'},
#  {'common_name': 'Atlantic Yellow-nosed Albatross',
#   'scientific_name': 'Thalassarche chlororhynchos',
#   'image_url': 'https://birda.twic.pics/species/9658895e-2d4e-4f08-92a3-26b7cb169ebf/reference_images/Atlantic_Yellow-nosed_Albatross-_F.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7359/Atlantic_Yellow-nosed_Albatross'},
#  {'common_name': 'Black-browed Albatross',
#   'scientific_name': 'Thalassarche melanophris',
#   'image_url': 'https://birda.twic.pics/species/5c010079-c4b9-4f03-b25f-d62fc3721b84/reference_images/Black-browed_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7346/Black-browed_Albatross'},
#  {'common_name': "Buller's Albatross",
#   'scientific_name': 'Thalassarche bulleri',
#   'image_url': 'https://birda.twic.pics/species/830a1f72-779e-4ec7-a071-db550ade3fb0/reference_images/Bullers_Albatross-_Flying.jpg',
#   'guide_url': "https://app.birda.org/species-guide/7363/Buller's_Albatross"},
#  {'common_name': 'Chatham Albatross',
#   'scientific_name': 'Thalassarche eremita',
#   'image_url': 'https://birda.twic.pics/species/651e9535-a77b-4935-9928-abee3c99938f/reference_images/Chatham_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7354/Chatham_Albatross'},
#  {'common_name': 'Grey-headed Albatross',
#   'scientific_name': 'Thalassarche chrysostoma',
#   'image_url': 'https://birda.twic.pics/species/a2f7f856-047a-48fd-ad86-8c80d5c46fb3/reference_images/Grey-headed_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7358/Grey-headed_Albatross'},
#  {'common_name': 'Indian Yellow-nosed Albatross',
#   'scientific_name': 'Thalassarche carteri',
#   'image_url': 'https://birda.twic.pics/species/101f574f-5bd5-428f-b2e4-2e7a404ed694/reference_images/Indian_Yellow-nosed_Albatross-_Fly.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7361/Indian_Yellow-nosed_Albatross'},
#  {'common_name': 'Laysan Albatross',
#   'scientific_name': 'Phoebastria immutabilis',
#   'image_url': 'https://birda.twic.pics/species/daf9ce02-ba95-45b8-8448-aaa00e529381/reference_images/Laysan_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7326/Laysan_Albatross'},
#  {'common_name': 'Light-mantled Albatross',
#   'scientific_name': 'Phoebetria palpebrata',
#   'image_url': 'https://birda.twic.pics/species/afa274d2-110e-4e14-877e-61cc7e156eba/reference_images/Light-mantled_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7345/Light-mantled_Albatross'},
#  {'common_name': 'Northern Royal Albatross',
#   'scientific_name': 'Diomedea sanfordi',
#   'image_url': 'https://birda.twic.pics/species/ddac2342-8503-4445-96d7-c15e70776b7c/reference_images/Northern_Royal_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7342/Northern_Royal_Albatross'},
#  {'common_name': "Salvin's Albatross",
#   'scientific_name': 'Thalassarche salvini',
#   'image_url': 'https://birda.twic.pics/species/653870bd-1fb9-4df8-8d1a-9074cb7254e6/reference_images/Salvins_Albatross-_Flying.jpg',
#   'guide_url': "https://app.birda.org/species-guide/7356/Salvin's_Albatross"},
#  {'common_name': 'Shy Albatross',
#   'scientific_name': 'Thalassarche cauta',
#   'image_url': 'https://birda.twic.pics/species/f01a8aa2-647e-4a0e-b3fc-11370267f397/reference_images/Shy_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7350/Shy_Albatross'},
#  {'common_name': 'Sooty Albatross',
#   'scientific_name': 'Phoebetria fusca',
#   'image_url': 'https://birda.twic.pics/species/66aa5196-c4e4-4f6b-b39e-3bb90119372f/reference_images/Sooty_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7344/Sooty_Albatross'},
#  {'common_name': 'Southern Royal Albatross',
#   'scientific_name': 'Diomedea epomophora',
#   'image_url': 'https://birda.twic.pics/species/e48066a1-5884-4d96-98c5-cd5cdbf1ad26/reference_images/Southern_Royal_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7340/Southern_Royal_Albatross'},
#  {'common_name': 'Tristan Albatross',
#   'scientific_name': 'Diomedea dabbenena',
#   'image_url': 'https://birda.twic.pics/species/4b3ed544-c152-4329-8e5d-4c9f598d371d/reference_images/Tristan_Albatross-_Male-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7338/Tristan_Albatross'},
#  {'common_name': 'Wandering Albatross',
#   'scientific_name': 'Diomedea exulans',
#   'image_url': 'https://birda.twic.pics/species/5ba92fd8-49e5-4b6e-a0e5-848bef70c600/reference_images/Wandering_Albatross-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7330/Wandering_Albatross'},
#  {'common_name': 'African Darter',
#   'scientific_name': 'Anhinga rufa',
#   'image_url': 'https://birda.twic.pics/species/c7eb3a72-a1e2-4ab3-8758-a120e6b600c5/reference_images/African_Darter.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7660/African_Darter'},
#  {'common_name': 'Black-bellied Storm Petrel',
#   'scientific_name': 'Fregetta tropica',
#   'image_url': 'https://birda.twic.pics/species/9e0040c2-e2fa-48f6-9d23-829ee9544634/reference_images/Black-bellied_Storm_Petrel-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7321/Black-bellied_Storm_Petrel'},
#  {'common_name': 'Grey-backed Storm Petrel',
#   'scientific_name': 'Garrodia nereis',
#   'image_url': 'https://birda.twic.pics/species/2f4f4c54-d300-4f2e-b420-e12289df12f4/reference_images/Grey-backed_Storm_Petrel-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7307/Grey-backed_Storm_Petrel'},
#  {'common_name': 'White-bellied Storm Petrel',
#   'scientific_name': 'Fregetta grallaria',
#   'image_url': 'https://birda.twic.pics/species/2599edfb-fda2-4ae2-ac8b-8828d4971f7f/reference_images/White-bellied_Storm_Petrel-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7315/White-bellied_Storm_Petrel'},
#  {'common_name': 'White-faced Storm Petrel',
#   'scientific_name': 'Pelagodroma marina',
#   'image_url': 'https://birda.twic.pics/species/65bd12a1-bc89-47ec-ab77-89abaa01f705/reference_images/White-faced_Strom-petrel-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/7308/White-faced_Storm_Petrel'},
#  {'common_name': "Wilson's Petrel",
#   'scientific_name': 'Oceanites oceanicus',
#   'image_url': 'https://birda.twic.pics/species/acf9fca8-af42-4be5-9514-d590e290de5f/reference_images/Wilsons_Storm_Petrel-_Flying.jpg',
#   'guide_url': "https://app.birda.org/species-guide/7299/Wilson's_Storm_Petrel"},
#  {'common_name': 'African Grass Owl',
#   'scientific_name': 'Tyto capensis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/8871/African_Grass_Owl'},
#  {'common_name': 'Barn Owl',
#   'scientific_name': 'Tyto alba',
#   'image_url': 'https://birda.twic.pics/species/f32f5a0b-0fc4-49dc-a107-9ab226ead556/reference_images/Western_Barn_Owl.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/8827/Western_Barn_Owl'},
#  {'common_name': 'Bee-eater',
#   'scientific_name': 'Merops apiaster',
#   'image_url': 'https://birda.twic.pics/species/6e4bbd2f-276e-4108-81d8-c174e7da9907/reference_images/European_Bee-eater-_New.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10826/European_Bee-eater'},
#  {'common_name': 'Blue-cheeked Bee-eater',
#   'scientific_name': 'Merops persicus',
#   'image_url': 'https://birda.twic.pics/species/5ed22609-a1f8-4e78-8520-943681f125db/reference_images/Blue-cheeked_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10806/Blue-cheeked_Bee-eater'},
#  {'common_name': "Böhm's Bee-eater",
#   'scientific_name': 'Merops boehmi',
#   'image_url': 'N/A',
#   'guide_url': "https://app.birda.org/species-guide/10792/B%C3%B6hm's_Bee-eater"},
#  {'common_name': 'Little Bee-eater',
#   'scientific_name': 'Merops pusillus',
#   'image_url': 'https://birda.twic.pics/species/be43697b-8003-45cb-86f0-1ca3e76de6c8/reference_images/Little_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10770/Little_Bee-eater'},
#  {'common_name': 'Northern Carmine Bee-eater',
#   'scientific_name': 'Merops nubicus',
#   'image_url': 'https://birda.twic.pics/species/f2654333-0592-4a78-91b8-1c1df8b7e37e/reference_images/Northern_Carmine_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10828/Northern_Carmine_Bee-eater'},
#  {'common_name': 'Olive Bee-eater',
#   'scientific_name': 'Merops superciliosus',
#   'image_url': 'https://birda.twic.pics/species/277dc013-c712-46e4-8c17-fb6157bf3233/reference_images/Olive_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10809/Olive_Bee-eater'},
#  {'common_name': 'Southern Carmine Bee-eater',
#   'scientific_name': 'Merops nubicoides',
#   'image_url': 'https://birda.twic.pics/species/76420bb5-9b59-4088-8d8d-2af12f7bea07/reference_images/Southern_Carmine_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10830/Southern_Carmine_Bee-eater'},
#  {'common_name': 'Swallow-tailed Bee-eater',
#   'scientific_name': 'Merops hirundineus',
#   'image_url': 'https://birda.twic.pics/species/9ee7119a-4106-431c-a0ea-1b6c840bf6b0/reference_images/Swallow-tailed_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10765/Swallow-tailed_Bee-eater'},
#  {'common_name': 'White-fronted Bee-eater',
#   'scientific_name': 'Merops bullockoides',
#   'image_url': 'https://birda.twic.pics/species/4c097131-9342-44cb-a840-7bad3ca9076a/reference_images/White-fronted_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10787/White-fronted_Bee-eater'},
#  {'common_name': 'White-throated Bee-eater',
#   'scientific_name': 'Merops albicollis',
#   'image_url': 'https://birda.twic.pics/species/8fa1c9f5-0f20-405e-af83-7c69524e8b27/reference_images/White-throated_Bee-eater.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/10791/White-throated_Bee-eater'},
#  {'common_name': 'African Red-eyed Bulbul',
#   'scientific_name': 'Pycnonotus nigricans',
#   'image_url': 'https://birda.twic.pics/species/d4d9e9df-5f1e-409b-acad-17eedbbd03b4/reference_images/African_Red-eyed_Bulbul.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24620/African_Red-eyed_Bulbul'},
#  {'common_name': 'Cape Bulbul',
#   'scientific_name': 'Pycnonotus capensis',
#   'image_url': 'https://birda.twic.pics/species/7788f633-6329-407a-9c29-edfb0f0b63dc/reference_images/Cape_Bulbul.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24646/Cape_Bulbul'},
#  {'common_name': 'Dark-capped Bulbul',
#   'scientific_name': 'Pycnonotus tricolor',
#   'image_url': 'https://birda.twic.pics/species/96ddcd54-f2d0-4b3b-9010-e54c7b639b70/reference_images/Dark-capped_Bulbul_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24637/Dark-capped_Bulbul'},
#  {'common_name': 'Lowland Tiny Greenbul',
#   'scientific_name': 'Phyllastrephus debilis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/24227/Lowland_Tiny_Greenbul'},
#  {'common_name': 'Sombre Greenbul',
#   'scientific_name': 'Andropadus importunus',
#   'image_url': 'https://birda.twic.pics/species/3508bdc0-4f89-448e-a958-359348c4e6cb/reference_images/Sombre_Greenbul_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24105/Sombre_Greenbul'},
#  {'common_name': 'Stripe-cheeked Greenbul',
#   'scientific_name': 'Arizelocichla milanjensis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/24188/Stripe-cheeked_Greenbul'},
#  {'common_name': 'Terrestrial Brownbul',
#   'scientific_name': 'Phyllastrephus terrestris',
#   'image_url': 'https://birda.twic.pics/species/9b017f9e-1781-4abe-9bec-8d529c0d8528/reference_images/Terrestrial_Brownbul.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24243/Terrestrial_Brownbul'},
#  {'common_name': 'Yellow-bellied Greenbul',
#   'scientific_name': 'Chlorocichla flaviventris',
#   'image_url': 'https://birda.twic.pics/species/0e1645e8-7a51-4b46-ac45-9a66f576c58b/reference_images/Yellow-bellied_Greenbul.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/24153/Yellow-bellied_Greenbul'},
#  {'common_name': 'Yellow-streaked Greenbul',
#   'scientific_name': 'Phyllastrephus flavostriatus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/24269/Yellow-streaked_Greenbul'},
#  {'common_name': 'Yellow-throated Leaflove',
#   'scientific_name': 'Atimastillas flavicollis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/24135/Yellow-throated_Leaflove'},
#  {'common_name': "Cabanis's Bunting",
#   'scientific_name': 'Emberiza cabanisi',
#   'image_url': 'N/A',
#   'guide_url': "https://app.birda.org/species-guide/34420/Cabanis's_Bunting"},
#  {'common_name': 'Cape Bunting',
#   'scientific_name': 'Emberiza capensis',
#   'image_url': 'https://birda.twic.pics/species/c17c5221-5168-41b2-81aa-ab250258f9c5/reference_images/Cape_Bunting.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/34379/Cape_Bunting'},
#  {'common_name': 'Cinnamon-breasted Bunting',
#   'scientific_name': 'Emberiza tahapisi',
#   'image_url': 'https://birda.twic.pics/species/3e9fb780-95d8-4d96-ac30-bd51ddcf9930/reference_images/Cinnamon-breasted_Bunting-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/34370/Cinnamon-breasted_Bunting'},
#  {'common_name': 'Golden-breasted Bunting',
#   'scientific_name': 'Emberiza flaviventris',
#   'image_url': 'https://birda.twic.pics/species/8c881ab9-7e2f-4901-8042-6fcc0f35d6a9/reference_images/Golden-breasted_Bunting-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/34410/Golden-breasted_Bunting'},
#  {'common_name': 'Lark-like Bunting',
#   'scientific_name': 'Emberiza impetuani',
#   'image_url': 'https://birda.twic.pics/species/407f14c4-60fe-48d5-940f-9c3a60baacf6/reference_images/Lark-like_Bunting.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/34366/Lark-like_Bunting'},
#  {'common_name': 'Ortolan Bunting',
#   'scientific_name': 'Emberiza hortulana',
#   'image_url': 'https://birda.twic.pics/species/67578d1c-d805-4d0c-b2ee-489d5da069ea/reference_images/Ortolan_Bunting.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/34354/Ortolan_Bunting'},
#  {'common_name': 'Black-backed Puffback',
#   'scientific_name': 'Dryoscopus cubla',
#   'image_url': 'https://birda.twic.pics/species/9effc54b-da00-49c7-98c4-950eb913e4ec/reference_images/Black-backed_Puffback-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19929/Black-backed_Puffback'},
#  {'common_name': 'Black-crowned Tchagra',
#   'scientific_name': 'Tchagra senegalus',
#   'image_url': 'https://birda.twic.pics/species/b8a37a85-3448-4e1d-b0ed-ca5bc70422f2/reference_images/Black-crowned_Tchagra.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19905/Black-crowned_Tchagra'},
#  {'common_name': 'Black-fronted Bushshrike',
#   'scientific_name': 'Chlorophoneus nigrifrons',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19847/Black-fronted_Bushshrike'},
#  {'common_name': 'Bokmakierie',
#   'scientific_name': 'Telophorus zeylonus',
#   'image_url': 'https://birda.twic.pics/species/235ce9a9-a02f-4c2d-8613-c615ce76274f/reference_images/Bokmakierie.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19870/Bokmakierie'},
#  {'common_name': 'Brown-crowned Tchagra',
#   'scientific_name': 'Tchagra australis',
#   'image_url': 'https://birda.twic.pics/species/bdc13101-16d2-41cd-9483-a31c565bbe2f/reference_images/Brown-crowned_Tchagra.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19886/Brown-crowned_Tchagra'},
#  {'common_name': 'Brubru',
#   'scientific_name': 'Nilaus afer',
#   'image_url': 'https://birda.twic.pics/species/c3aa196f-0270-47c3-8340-0eda123192f4/reference_images/Brubru-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/20002/Brubru'},
#  {'common_name': 'Crimson-breasted Shrike',
#   'scientific_name': 'Laniarius atrococcineus',
#   'image_url': 'https://birda.twic.pics/species/0120948f-2302-4d43-bb6c-f3b88dd34868/reference_images/Crimson-breasted_Shrike.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/20000/Crimson-breasted_Shrike'},
#  {'common_name': 'Gorgeous Bushshrike',
#   'scientific_name': 'Telophorus viridis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19863/Gorgeous_Bushshrike'},
#  {'common_name': 'Grey-headed Bushshrike',
#   'scientific_name': 'Malaconotus blanchoti',
#   'image_url': 'https://birda.twic.pics/species/c4b6b608-8300-494b-b4a5-1d44728eeef1/reference_images/Grey-headed_Bushshrike.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19829/Grey-headed_Bushshrike'},
#  {'common_name': 'Marsh Tchagra',
#   'scientific_name': 'Bocagia minuta',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19880/Marsh_Tchagra'},
#  {'common_name': 'Olive Bushshrike',
#   'scientific_name': 'Chlorophoneus olivaceus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19851/Olive_Bushshrike'},
#  {'common_name': 'Orange-breasted Bushshrike',
#   'scientific_name': 'Chlorophoneus sulfureopectus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19860/Orange-breasted_Bushshrike'},
#  {'common_name': 'Southern Boubou',
#   'scientific_name': 'Laniarius ferrugineus',
#   'image_url': 'https://birda.twic.pics/species/08fd4467-755d-434e-9529-ce321ed9c707/reference_images/Southern_Boubou_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19981/Southern_Boubou'},
#  {'common_name': 'Southern Tchagra',
#   'scientific_name': 'Tchagra tchagra',
#   'image_url': 'https://birda.twic.pics/species/a71a6303-b68a-47df-ac95-c37e9cebed17/reference_images/Southern_Tchargra.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19901/Southern_Tchagra'},
#  {'common_name': 'Swamp Boubou',
#   'scientific_name': 'Laniarius bicolor',
#   'image_url': 'https://birda.twic.pics/species/f42b1e30-c60a-43d4-9055-e77c4321a508/reference_images/Swamp_Boubou.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/19988/Swamp_Boubou'},
#  {'common_name': 'Tropical Boubou',
#   'scientific_name': 'Laniarius major',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/19973/Tropical_Boubou'},
#  {'common_name': 'Black-bellied Bustard',
#   'scientific_name': 'Lissotis melanogaster',
#   'image_url': 'https://birda.twic.pics/species/2008d859-53be-46a6-9605-b294d9cf2e39/reference_images/Black-bellied_Bustard-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3828/Black-bellied_Bustard'},
#  {'common_name': 'Blue Korhaan',
#   'scientific_name': 'Eupodotis caerulescens',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/3805/Blue_Korhaan'},
#  {'common_name': "Denham's Bustard",
#   'scientific_name': 'Neotis denhami',
#   'image_url': 'https://birda.twic.pics/species/8a6fd42c-4036-4555-845f-adcdfc076d96/reference_images/Denhams_Bustard-_Male.jpg',
#   'guide_url': "https://app.birda.org/species-guide/3790/Denham's_Bustard"},
#  {'common_name': 'Karoo Korhaan',
#   'scientific_name': 'Eupodotis vigorsii',
#   'image_url': 'https://birda.twic.pics/species/8841b833-a5f3-4acf-b3a4-b09082b04c81/reference_images/Karoo_Korhaan.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3806/Karoo_Korhaan'},
#  {'common_name': 'Kori Bustard',
#   'scientific_name': 'Ardeotis kori',
#   'image_url': 'https://birda.twic.pics/species/56835cd0-b5ec-4191-afca-fff0259d65be/reference_images/Koi_Bustard.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3779/Kori_Bustard'},
#  {'common_name': "Ludwig's Bustard",
#   'scientific_name': 'Neotis ludwigii',
#   'image_url': 'https://birda.twic.pics/species/52fab9c8-9155-44d4-876e-8c5107ac27f8/reference_images/Ludwigs_Bustard-_Male.jpg',
#   'guide_url': "https://app.birda.org/species-guide/3789/Ludwig's_Bustard"},
#  {'common_name': 'Northern Black Korhaan',
#   'scientific_name': 'Afrotis afraoides',
#   'image_url': 'https://birda.twic.pics/species/7b89a181-fc57-45ae-b752-015bb3079473/reference_images/Northern_Black_Korhaan-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3822/Northern_Black_Korhaan'},
#  {'common_name': 'Red-crested Korhaan',
#   'scientific_name': 'Lophotis ruficrista',
#   'image_url': 'https://birda.twic.pics/species/b12d7c3f-a6c1-4f9c-ac27-09fd5100e562/reference_images/Red-crested_Korhaan-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3818/Red-crested_Korhaan'},
#  {'common_name': "Rüppell's Korhaan",
#   'scientific_name': 'Eupodotis rueppelii',
#   'image_url': 'https://birda.twic.pics/species/cf45ef14-d3c6-49a7-92a3-a508daa8aa71/reference_images/Ruppells_Korhaan-_Male.jpg',
#   'guide_url': "https://app.birda.org/species-guide/3809/R%C3%BCppell's_Korhaan"},
#  {'common_name': 'Southern Black Korhaan',
#   'scientific_name': 'Afrotis afra',
#   'image_url': 'https://birda.twic.pics/species/ec025501-6c81-437d-a760-adc3c0c4d52c/reference_images/Southern_Blck_Korhaan-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3820/Southern_Black_Korhaan'},
#  {'common_name': 'White-bellied Bustard',
#   'scientific_name': 'Eupodotis senegalensis',
#   'image_url': 'https://birda.twic.pics/species/2d80dc75-45c0-4030-a2ce-ebca7b8fdafc/reference_images/White-bellied_Bustard-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/3798/White-bellied_Bustard'},
#  {'common_name': 'Black-rumped Buttonquail',
#   'scientific_name': 'Turnix nanus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/6271/Black-rumped_Buttonquail'},
#  {'common_name': 'Common Buttonquail',
#   'scientific_name': 'Turnix sylvaticus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/6242/Common_Buttonquail'},
#  {'common_name': 'Fynbos Buttonquail',
#   'scientific_name': 'Turnix hottentottus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/6269/Fynbos_Buttonquail'},
#  {'common_name': 'African Hobby',
#   'scientific_name': 'Falco cuvierii',
#   'image_url': 'https://birda.twic.pics/species/120bca99-014f-4fbc-bfea-277e8c981785/reference_images/African_Hobby.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12834/African_Hobby'},
#  {'common_name': 'Amur Falcon',
#   'scientific_name': 'Falco amurensis',
#   'image_url': 'https://birda.twic.pics/species/918ba15d-ba4f-4a09-bc42-ba13502a1f67/reference_images/Amur_Falcon-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12809/Amur_Falcon'},
#  {'common_name': "Dickinson's Kestrel",
#   'scientific_name': 'Falco dickinsoni',
#   'image_url': 'https://birda.twic.pics/species/80251084-32f3-42e5-baf4-c11593e6d1f6/reference_images/Dickinsons_Kestrel.jpg',
#   'guide_url': "https://app.birda.org/species-guide/12801/Dickinson's_Kestrel"},
#  {'common_name': "Eleonora's Falcon",
#   'scientific_name': 'Falco eleonorae',
#   'image_url': 'https://birda.twic.pics/species/f0c05774-0643-49de-b765-3137fdf2e193/reference_images/Eleonoras_Falcon-_Flying.jpg',
#   'guide_url': "https://app.birda.org/species-guide/12810/Eleonora's_Falcon"},
#  {'common_name': 'Greater Kestrel',
#   'scientific_name': 'Falco rupicoloides',
#   'image_url': 'https://birda.twic.pics/species/5dbccf2f-b88c-4dd5-9fa1-ec97b9cf5319/reference_images/Greater_Kestrel.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12795/Greater_Kestrel'},
#  {'common_name': 'Grey Kestrel',
#   'scientific_name': 'Falco ardosiaceus',
#   'image_url': 'https://birda.twic.pics/species/f76fdb2d-b4ba-4943-9ec4-4afe6aab87d3/reference_images/Grey_Kestrel-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12800/Grey_Kestrel'},
#  {'common_name': 'Hobby',
#   'scientific_name': 'Falco subbuteo',
#   'image_url': 'https://birda.twic.pics/species/a52c7005-b28b-4edf-bfd6-c6a5784be77a/reference_images/Eurasian_Hobby_-_Adult_-_Perched.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12831/Eurasian_Hobby'},
#  {'common_name': 'Lanner Falcon',
#   'scientific_name': 'Falco biarmicus',
#   'image_url': 'https://birda.twic.pics/species/b7788035-d571-4a49-b894-6db533a662ef/reference_images/Lanner_Falcon-_Flying-_New.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12852/Lanner_Falcon'},
#  {'common_name': 'Lesser Kestrel',
#   'scientific_name': 'Falco naumanni',
#   'image_url': 'https://birda.twic.pics/species/f442edf4-7ff2-4d12-8220-1f15d343b01d/reference_images/Lesser_Kestrel_-_Male_-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12746/Lesser_Kestrel'},
#  {'common_name': 'Peregrine',
#   'scientific_name': 'Falco peregrinus',
#   'image_url': 'https://birda.twic.pics/species/968d43a6-b497-4221-b70e-edaabdfc1c4d/reference_images/Peregrine_Falcon_-_Standing.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12871/Peregrine_Falcon'},
#  {'common_name': 'Pygmy Falcon',
#   'scientific_name': 'Polihierax semitorquatus',
#   'image_url': 'https://birda.twic.pics/species/023efe82-923f-4d60-9ed3-0db88d47ecb1/reference_images/Pygmy_Falcon-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12730/Pygmy_Falcon'},
#  {'common_name': 'Red-footed Falcon',
#   'scientific_name': 'Falco vespertinus',
#   'image_url': 'https://birda.twic.pics/species/39078667-aee1-4fa0-88e6-8879b547cae3/reference_images/Red-footed_Falcon_-_Male_-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12808/Red-footed_Falcon'},
#  {'common_name': 'Red-necked Falcon',
#   'scientific_name': 'Falco chicquera',
#   'image_url': 'https://birda.twic.pics/species/948b8280-2a9a-4e82-94bf-f63f36892ffb/reference_images/Red-necked_Falcon-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12803/Red-necked_Falcon'},
#  {'common_name': 'Red-necked Falcon',
#   'scientific_name': 'Falco chicquera',
#   'image_url': 'https://birda.twic.pics/species/948b8280-2a9a-4e82-94bf-f63f36892ffb/reference_images/Red-necked_Falcon-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12803/Red-necked_Falcon'},
#  {'common_name': 'Red-necked Falcon',
#   'scientific_name': 'Falco chicquera',
#   'image_url': 'https://birda.twic.pics/species/948b8280-2a9a-4e82-94bf-f63f36892ffb/reference_images/Red-necked_Falcon-_Flying.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12803/Red-necked_Falcon'},
#  {'common_name': 'Rock Kestrel',
#   'scientific_name': 'Falco rupicolus',
#   'image_url': 'https://birda.twic.pics/species/d24a9c32-993f-46a6-b83a-9d22327779e7/reference_images/Rock_Kestrel.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/12759/Rock_Kestrel'},
#  {'common_name': 'Sooty Falcon',
#   'scientific_name': 'Falco concolor',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/12811/Sooty_Falcon'},
#  {'common_name': 'Taita Falcon',
#   'scientific_name': 'Falco fasciinucha',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/12893/Taita_Falcon'},
#  {'common_name': 'African Dusky Flycatcher',
#   'scientific_name': 'Muscicapa adusta',
#   'image_url': 'https://birda.twic.pics/species/d659a365-82bf-4e0d-914f-e66299aba855/reference_images/African_Dusky_Flycatcher.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30522/African_Dusky_Flycatcher'},
#  {'common_name': 'African Stonechat',
#   'scientific_name': 'Saxicola torquatus',
#   'image_url': 'https://birda.twic.pics/species/25c21d97-d390-4fa2-b502-e7f0a4beb3f0/reference_images/African_Stonechat_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31225/African_Stonechat'},
#  {'common_name': 'Angolan Cave Chat',
#   'scientific_name': 'Xenocopsychus ansorgei',
#   'image_url': 'https://birda.twic.pics/species/da62bfa4-122c-4658-88b4-fb5153bca79c/reference_images/Angolan_Cave_Chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30763/Angolan_Cave_Chat'},
#  {'common_name': 'Ant-eating Chat',
#   'scientific_name': 'Myrmecocichla formicivora',
#   'image_url': 'https://birda.twic.pics/species/04ef3cf7-d91c-4524-92f3-ae7259c14896/reference_images/Ant-eating_Chat-_Male_.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31312/Ant-eating_Chat'},
#  {'common_name': "Arnot's Chat",
#   'scientific_name': 'Myrmecocichla arnotti',
#   'image_url': 'https://birda.twic.pics/species/aa03f501-dc23-4862-af19-f7db37ac499c/reference_images/Arnots_Chat-_Male.jpg',
#   'guide_url': "https://app.birda.org/species-guide/31320/Arnot's_Chat"},
#  {'common_name': 'Ashy Flycatcher',
#   'scientific_name': 'Muscicapa caerulescens',
#   'image_url': 'https://birda.twic.pics/species/e4d87cca-e426-42e2-a3fc-7025f92d2a57/reference_images/Ashy_Flycatcher.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30502/Ashy_Flycatcher'},
#  {'common_name': 'Bearded Scrub Robin',
#   'scientific_name': 'Cercotrichas quadrivirgata',
#   'image_url': 'https://birda.twic.pics/species/714c24c5-548b-44cb-89fa-3ab2e9f2aec7/reference_images/Bearded_Scrub-robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30289/Bearded_Scrub_Robin'},
#  {'common_name': 'Brown Scrub Robin',
#   'scientific_name': 'Cercotrichas signata',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/30324/Brown_Scrub_Robin'},
#  {'common_name': 'Buff-streaked Chat',
#   'scientific_name': 'Campicoloides bifasciatus',
#   'image_url': 'https://birda.twic.pics/species/7d43e891-0322-478d-96a4-dae4a5196cc0/reference_images/Buff-streaked_Chat-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31272/Buff-streaked_Chat'},
#  {'common_name': 'Cape Robin-Chat',
#   'scientific_name': 'Cossypha caffra',
#   'image_url': 'https://birda.twic.pics/species/329612a0-26b1-4924-80d3-c38e206028cf/reference_images/Cape_Robin-Chat_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30754/Cape_Robin-Chat'},
#  {'common_name': 'Cape Rock Thrush',
#   'scientific_name': 'Monticola rupestris',
#   'image_url': 'https://birda.twic.pics/species/bcf55046-c22d-4c7f-bb81-51954339d76d/reference_images/Cape_Rock_Thrush-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31171/Cape_Rock_Thrush'},
#  {'common_name': 'Capped Wheatear',
#   'scientific_name': 'Oenanthe pileata',
#   'image_url': 'https://birda.twic.pics/species/ede81582-3c65-4359-a2c9-83e00e3aad89/reference_images/Capped_Wheatear.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31333/Capped_Wheatear'},
#  {'common_name': 'Chat Flycatcher',
#   'scientific_name': 'Melaenornis infuscatus',
#   'image_url': 'https://birda.twic.pics/species/c2eac793-71fc-4741-acf2-6b122bd12016/reference_images/Chat_Flycatcher.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30448/Chat_Flycatcher'},
#  {'common_name': 'Chorister Robin-Chat',
#   'scientific_name': 'Cossypha dichroa',
#   'image_url': 'https://birda.twic.pics/species/b33f3474-2956-43b0-8977-15ce93b1affb/reference_images/Chorister_Robin-chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30789/Chorister_Robin-Chat'},
#  {'common_name': 'Collared Flycatcher',
#   'scientific_name': 'Ficedula albicollis',
#   'image_url': 'https://birda.twic.pics/species/18b74fbd-0a19-49de-8d44-5f10bb4c6b32/reference_images/Collared_Flycatcher-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31102/Collared_Flycatcher'},
#  {'common_name': 'Collared Palm Thrush',
#   'scientific_name': 'Cichladusa arquata',
#   'image_url': 'https://birda.twic.pics/species/a3e45703-1c40-48ce-a70d-c4f713192b04/reference_images/Collared_Palm_Thrush.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30860/Collared_Palm_Thrush'},
#  {'common_name': 'East Coast Akalat',
#   'scientific_name': 'Sheppardia gunningi',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/30851/East_Coast_Akalat'},
#  {'common_name': 'Familiar Chat',
#   'scientific_name': 'Oenanthe familiaris',
#   'image_url': 'https://birda.twic.pics/species/04079090-8bfa-41b8-aea1-47ab8372fa78/reference_images/Familiar_Chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31377/Familiar_Chat'},
#  {'common_name': 'Fiscal Flycatcher',
#   'scientific_name': 'Melaenornis silens',
#   'image_url': 'https://birda.twic.pics/species/8716aeb9-b230-4e6f-b015-30cb8cec600b/reference_images/Fiscal_Flycatcher-_Male_.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30465/Fiscal_Flycatcher'},
#  {'common_name': 'Grey Tit-Flycatcher',
#   'scientific_name': 'Myioparus plumbeus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/30406/Grey_Tit-Flycatcher'},
#  {'common_name': 'Herero Chat',
#   'scientific_name': 'Namibornis herero',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/31425/Herero_Chat'},
#  {'common_name': 'Isabelline Wheatear',
#   'scientific_name': 'Oenanthe isabellina',
#   'image_url': 'https://birda.twic.pics/species/025c2099-61d0-400a-bdef-3d3f6e991c9c/reference_images/Isabelline_Wheatear.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31344/Isabelline_Wheatear'},
#  {'common_name': 'Kalahari Scrub Robin',
#   'scientific_name': 'Cercotrichas paena',
#   'image_url': 'https://birda.twic.pics/species/2d5d497b-c174-4825-975f-670f3f70c5da/reference_images/Kalahari_Scrub_Robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30305/Kalahari_Scrub_Robin'},
#  {'common_name': 'Karoo Chat',
#   'scientific_name': 'Emarginata schlegelii',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/31277/Karoo_Chat'},
#  {'common_name': 'Karoo Scrub Robin',
#   'scientific_name': 'Cercotrichas coryphoeus',
#   'image_url': 'https://birda.twic.pics/species/1c891bc1-68b7-45a8-a703-564d69102ba7/reference_images/Karoo_Scrub_Robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30280/Karoo_Scrub_Robin'},
#  {'common_name': 'Marico Flycatcher',
#   'scientific_name': 'Melaenornis mariquensis',
#   'image_url': 'https://birda.twic.pics/species/cb404195-d16b-466f-b803-692f8acf0891/reference_images/Marico_Flycatcher.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30461/Marico_Flycatcher'},
#  {'common_name': 'Mediterranean Flycatcher',
#   'scientific_name': 'Muscicapa tyrrhenica',
#   'image_url': 'https://birda.twic.pics/species/6c4e29e7-8b2d-4a7d-b996-f942507fb37f/reference_images/Mediterranean_Flycatcher-_New.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30477/Mediterranean_Flycatcher'},
#  {'common_name': 'Miombo Rock Thrush',
#   'scientific_name': 'Monticola angolensis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/31180/Miombo_Rock_Thrush'},
#  {'common_name': 'Mocking Cliff Chat',
#   'scientific_name': 'Thamnolaea cinnamomeiventris',
#   'image_url': 'https://birda.twic.pics/species/138530d9-bc2d-4c35-bb3e-a19571a9e3a9/reference_images/Mocking_Cliff_Chat-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31295/Mocking_Cliff_Chat'},
#  {'common_name': 'Mountain Wheatear',
#   'scientific_name': 'Myrmecocichla monticola',
#   'image_url': 'https://birda.twic.pics/species/c42ba9b9-630f-4096-9db6-a7c4e4007eba/reference_images/Mountain_Wheatear-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31314/Mountain_Wheatear'},
#  {'common_name': 'Pale Flycatcher',
#   'scientific_name': 'Melaenornis pallidus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/30434/Pale_Flycatcher'},
#  {'common_name': 'Pied Flycatcher',
#   'scientific_name': 'Ficedula hypoleuca',
#   'image_url': 'https://birda.twic.pics/species/fafe083d-3627-44fb-b7a1-7eb86482536d/reference_images/European_Pied_Flycatcher_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31098/European_Pied_Flycatcher'},
#  {'common_name': 'Pied Wheatear',
#   'scientific_name': 'Oenanthe pleschanka',
#   'image_url': 'https://birda.twic.pics/species/0fddab01-4a2c-4662-b531-1197bc6e6bd0/reference_images/Pied_Wheatear_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31357/Pied_Wheatear'},
#  {'common_name': 'Red-capped Robin-Chat',
#   'scientific_name': 'Cossypha natalensis',
#   'image_url': 'https://birda.twic.pics/species/a3140fb1-f438-4884-99a4-4200be25fda4/reference_images/Red-capped_Robin-Chat_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30782/Red-capped_Robin-Chat'},
#  {'common_name': 'Redstart',
#   'scientific_name': 'Phoenicurus phoenicurus',
#   'image_url': 'https://birda.twic.pics/species/13da3581-cf90-4bed-9ae5-c61cdba9ee92/reference_images/Common_Redstart_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31152/Common_Redstart'},
#  {'common_name': 'Rufous-tailed Palm Thrush',
#   'scientific_name': 'Cichladusa ruficauda',
#   'image_url': 'https://birda.twic.pics/species/5070dfb7-1acf-4d2e-9dc6-0fc2073dc834/reference_images/Rufous-tailed_Palm_Thrush.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30861/Rufous-tailed_Palm_Thrush'},
#  {'common_name': 'Rufous-tailed Scrub Robin',
#   'scientific_name': 'Cercotrichas galactotes',
#   'image_url': 'https://birda.twic.pics/species/0761f204-bcfe-46b0-b2da-738c945e5e9e/reference_images/Rufous-tailed_Scrub_Robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30299/Rufous-tailed_Scrub_Robin'},
#  {'common_name': 'Sentinel Rock Thrush',
#   'scientific_name': 'Monticola explorator',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/31172/Sentinel_Rock_Thrush'},
#  {'common_name': 'Short-toed Rock Thrush',
#   'scientific_name': 'Monticola brevipes',
#   'image_url': 'https://birda.twic.pics/species/8218e7be-8b0e-4259-9061-d6e1f0657b7b/reference_images/Short-toed_Rock-thrush-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31175/Short-toed_Rock_Thrush'},
#  {'common_name': 'Sickle-winged Chat',
#   'scientific_name': 'Emarginata sinuata',
#   'image_url': 'https://birda.twic.pics/species/25caec36-58b7-422f-ab7d-1e5d5521efcc/reference_images/Sickle-winged_Chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31273/Sickle-winged_Chat'},
#  {'common_name': 'Southern Black Flycatcher',
#   'scientific_name': 'Melaenornis pammelaina',
#   'image_url': 'https://birda.twic.pics/species/661d5e78-d2b8-4f36-aee9-787e1c9bd9eb/reference_images/Southern_Black_Flycatcher_-_Adult.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30428/Southern_Black_Flycatcher'},
#  {'common_name': 'Spotted Flycatcher',
#   'scientific_name': 'Muscicapa striata',
#   'image_url': 'https://birda.twic.pics/species/a87cf477-961c-4e96-883e-67f209db926b/reference_images/Spotted_Flycatcher.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30471/Spotted_Flycatcher'},
#  {'common_name': "Swynnerton's Robin",
#   'scientific_name': 'Swynnertonia swynnertoni',
#   'image_url': 'N/A',
#   'guide_url': "https://app.birda.org/species-guide/30800/Swynnerton's_Robin"},
#  {'common_name': 'Thrush Nightingale',
#   'scientific_name': 'Luscinia luscinia',
#   'image_url': 'https://birda.twic.pics/species/90416342-1a7e-44e4-b4cd-b5897a1a5777/reference_images/Thrush_Nightingale.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30947/Thrush_Nightingale'},
#  {'common_name': 'Tractrac Chat',
#   'scientific_name': 'Emarginata tractrac',
#   'image_url': 'https://birda.twic.pics/species/9e957dc0-760c-473c-bdb7-0514f2a6403c/reference_images/Tractrac_Chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31283/Tractrac_Chat'},
#  {'common_name': 'Wheatear',
#   'scientific_name': 'Oenanthe oenanthe',
#   'image_url': 'https://birda.twic.pics/species/3fc55784-91e9-42f6-a1b9-6ebc24c86783/reference_images/Northern_Wheatear_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31325/Northern_Wheatear'},
#  {'common_name': 'Whinchat',
#   'scientific_name': 'Saxicola rubetra',
#   'image_url': 'https://birda.twic.pics/species/d2e1b56c-ddd8-4fcb-bac0-3e454d3b8545/reference_images/Whinchat_-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/31208/Whinchat'},
#  {'common_name': 'White-browed Robin-Chat',
#   'scientific_name': 'Cossypha heuglini',
#   'image_url': 'https://birda.twic.pics/species/d44d27de-b891-45fb-86c0-3e22f648cca6/reference_images/White-browed_Robin-chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30776/White-browed_Robin-Chat'},
#  {'common_name': 'White-browed Scrub Robin',
#   'scientific_name': 'Cercotrichas leucophrys',
#   'image_url': 'https://birda.twic.pics/species/736a518a-9b5f-4dae-b57f-e008e8a81ebf/reference_images/White-browed_Scrub_Robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30311/White-browed_Scrub_Robin'},
#  {'common_name': 'White-chested Alethe',
#   'scientific_name': 'Chamaetylas fuelleborni',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/30731/White-chested_Alethe'},
#  {'common_name': 'White-starred Robin',
#   'scientific_name': 'Pogonocichla stellata',
#   'image_url': 'https://birda.twic.pics/species/767675cc-b237-490f-90f8-b378ff2780b6/reference_images/White-starred_Robin.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30803/White-starred_Robin'},
#  {'common_name': 'White-throated Robin',
#   'scientific_name': 'Irania gutturalis',
#   'image_url': 'https://birda.twic.pics/species/f0a1e78e-0f34-4e88-8805-8dd00ac02fdc/reference_images/White-throated_Robin-_Male.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30952/White-throated_Robin'},
#  {'common_name': 'White-throated Robin-Chat',
#   'scientific_name': 'Cossypha humeralis',
#   'image_url': 'https://birda.twic.pics/species/2f0b8842-d98e-49e1-8fad-c61d2ae68574/reference_images/White-throated_Robin-chat.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/30760/White-throated_Robin-Chat'},
#  {'common_name': 'Barred Wren-Warbler',
#   'scientific_name': 'Calamonastes fasciolatus',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26478/Barred_Wren-Warbler'},
#  {'common_name': 'Bar-throated Apalis',
#   'scientific_name': 'Apalis thoracica',
#   'image_url': 'https://birda.twic.pics/species/358be887-b4ec-458c-98b6-0d93b20ab3fb/reference_images/Bar-throated_Apalis.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/26325/Bar-throated_Apalis'},
#  {'common_name': 'Black-chested Prinia',
#   'scientific_name': 'Prinia flavicans',
#   'image_url': 'https://birda.twic.pics/species/c82d55db-77be-45cb-a988-6a233f860471/reference_images/Black-chested_Prinia-_Breeding.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/26272/Black-chested_Prinia'},
#  {'common_name': 'Black-headed Apalis',
#   'scientific_name': 'Apalis melanocephala',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26386/Black-headed_Apalis'},
#  {'common_name': 'Burnt-necked Eremomela',
#   'scientific_name': 'Eremomela usticollis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26593/Burnt-necked_Eremomela'},
#  {'common_name': 'Chirinda Apalis',
#   'scientific_name': 'Apalis chirindensis',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26396/Chirinda_Apalis'},
#  {'common_name': 'Chirping Cisticola',
#   'scientific_name': 'Cisticola pipiens',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26021/Chirping_Cisticola'},
#  {'common_name': 'Cinnamon-breasted Warbler',
#   'scientific_name': 'Euryptila subcinnamomea',
#   'image_url': 'https://birda.twic.pics/species/6f85f502-bac2-4d14-80d8-29db5cf388f5/reference_images/Cinnamon-breasted_Warbler.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/26482/Cinnamon-breasted_Warbler'},
#  {'common_name': 'Cloud Cisticola',
#   'scientific_name': 'Cisticola textrix',
#   'image_url': 'N/A',
#   'guide_url': 'https://app.birda.org/species-guide/26122/Cloud_Cisticola'},
#  {'common_name': 'Croaking Cisticola',
#   'scientific_name': 'Cisticola natalensis',
#   'image_url': 'https://birda.twic.pics/species/ea17bd48-b004-41e2-9ab0-234343d44bc2/reference_images/Croaking_Cisticola.jpg',
#   'guide_url': 'https://app.birda.org/species-guide/26044/Croaking_Cisticola'},
#  {'common_name': 'Desert Cisticola',
#   'scientific_name': 'Cisticola aridulus',
#   'image_url': 'N/A',
# ...
#   'guide_url': '/species-guide/33074/Cut-throat_Finch'},
#  {'common_name': 'Green Twinspot',
#   'scientific_name': 'Mandingoa nitidula',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32953/Green_Twinspot'},
#  {'common_name': 'Green-winged Pytilia',
#   'scientific_name': 'Pytilia melba',
#   'image_url': 'https://birda.twic.pics/species/3caccbad-86a4-47f2-8bfe-37136db67d86/reference_images/Green-winged_Pytilia-_Male.jpg',
#   'guide_url': '/species-guide/33125/Green-winged_Pytilia'},
#  {'common_name': 'Grey Waxbill',
#   'scientific_name': 'Glaucestrilda perreini',
#   'image_url': 'https://birda.twic.pics/species/1ade53dd-60c6-4587-ac1f-251aa8a57010/reference_images/Grey_Waxbill.jpg',
#   'guide_url': '/species-guide/33003/Grey_Waxbill'},
#  {'common_name': "Jameson's Firefinch",
#   'scientific_name': 'Lagonosticta rhodopareia',
#   'image_url': 'https://birda.twic.pics/species/3ffb07cf-f2a9-47c3-9ad1-2a462725bdc2/reference_images/Jamesons_Firefinch-_Male.jpg',
#   'guide_url': "/species-guide/33171/Jameson's_Firefinch"},
#  {'common_name': 'Lesser Seedcracker',
#   'scientific_name': 'Pyrenestes minor',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/33117/Lesser_Seedcracker'},
#  {'common_name': 'Locust Finch',
#   'scientific_name': 'Paludipasser locustella',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/33071/Locust_Finch'},
#  {'common_name': 'Magpie Mannikin',
#   'scientific_name': 'Spermestes fringilloides',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32774/Magpie_Mannikin'},
#  {'common_name': 'Orange-breasted Waxbill',
#   'scientific_name': 'Amandava subflava',
#   'image_url': 'https://birda.twic.pics/species/9f4584af-bb67-4cbe-8c3c-6bb58f53db0a/reference_images/Orange-breasted_Waxbill-_Male.jpg',
#   'guide_url': '/species-guide/33083/Orange-breasted_Waxbill'},
#  {'common_name': 'Orange-winged Pytilia',
#   'scientific_name': 'Pytilia afra',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/33136/Orange-winged_Pytilia'},
#  {'common_name': 'Pink-throated Twinspot',
#   'scientific_name': 'Hypargos margaritatus',
#   'image_url': 'https://birda.twic.pics/species/df8b9c45-3289-4c6d-bb13-eb55a5ad884d/reference_images/Pink-throated_Twinspot-_Male.jpg',
#   'guide_url': '/species-guide/33152/Pink-throated_Twinspot'},
#  {'common_name': 'Quailfinch',
#   'scientific_name': 'Ortygospiza atricollis',
#   'image_url': 'https://birda.twic.pics/species/0a476792-0175-4372-b804-de4c4adc0ae8/reference_images/Quailfinch-_Male.jpg',
#   'guide_url': '/species-guide/33056/Quailfinch'},
#  {'common_name': 'Red-backed Mannikin',
#   'scientific_name': 'Spermestes nigriceps',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32779/Red-backed_Mannikin'},
#  {'common_name': 'Red-billed Firefinch',
#   'scientific_name': 'Lagonosticta senegala',
#   'image_url': 'https://birda.twic.pics/species/3b25193d-a22b-4857-b3f8-206de74338c7/reference_images/Red-billed_Firefinch-_Male.jpg',
#   'guide_url': '/species-guide/33154/Red-billed_Firefinch'},
#  {'common_name': 'Red-faced Crimsonwing',
#   'scientific_name': 'Cryptospiza reichenovii',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32964/Red-faced_Crimsonwing'},
#  {'common_name': 'Red-headed Finch',
#   'scientific_name': 'Amadina erythrocephala',
#   'image_url': 'https://birda.twic.pics/species/24d6572c-74cb-4366-a0c0-894ada630c52/reference_images/Red-headed_Finch-_Male.jpg',
#   'guide_url': '/species-guide/33079/Red-headed_Finch'},
#  {'common_name': 'Red-throated Twinspot',
#   'scientific_name': 'Hypargos niveoguttatus',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/33147/Red-throated_Twinspot'},
#  {'common_name': 'Swee Waxbill',
#   'scientific_name': 'Coccopygia melanotis',
#   'image_url': 'https://birda.twic.pics/species/344f16ce-4191-4294-8fe9-b0ce7271be03/reference_images/Swee_Waxbill-_Male.jpg',
#   'guide_url': '/species-guide/32951/Swee_Waxbill'},
#  {'common_name': 'Violet-eared Waxbill',
#   'scientific_name': 'Granatina granatina',
#   'image_url': 'https://birda.twic.pics/species/8d41a344-5c8b-4d7b-986d-2a4b97242a77/reference_images/Violet-eared_Waxbill-_Male.jpg',
#   'guide_url': '/species-guide/33094/Violet-eared_Waxbill'},
#  {'common_name': 'Yellow-bellied Waxbill',
#   'scientific_name': 'Coccopygia quartinia',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32945/Yellow-bellied_Waxbill'},
#  {'common_name': 'Black-winged Red Bishop',
#   'scientific_name': 'Euplectes hordeaceus',
#   'image_url': 'https://birda.twic.pics/species/02ed1631-702c-4ea9-a558-4e6317d82486/reference_images/Black-winged_Bishop-_Breeding-_Mal.jpg',
#   'guide_url': '/species-guide/32674/Black-winged_Red_Bishop'},
#  {'common_name': 'Cape Weaver',
#   'scientific_name': 'Ploceus capensis',
#   'image_url': 'https://birda.twic.pics/species/ee9c5e72-497e-489f-9117-6526da1dde39/reference_images/Cape_Weaver-_Male.jpg',
#   'guide_url': '/species-guide/32470/Cape_Weaver'},
#  {'common_name': 'Cardinal Quelea',
#   'scientific_name': 'Quelea cardinalis',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32636/Cardinal_Quelea'},
#  {'common_name': 'Chestnut Weaver',
#   'scientific_name': 'Ploceus rubiginosus',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32549/Chestnut_Weaver'},
#  {'common_name': 'Dark-backed Weaver',
#   'scientific_name': 'Ploceus bicolor',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32583/Dark-backed_Weaver'},
#  {'common_name': 'Eastern Golden Weaver',
#   'scientific_name': 'Ploceus subaureus',
#   'image_url': 'https://birda.twic.pics/species/d742a467-ff1d-4e12-b074-be4e03506e57/reference_images/Eastern_Golden_Weaver-_Male_.jpg',
#   'guide_url': '/species-guide/32475/Eastern_Golden_Weaver'},
#  {'common_name': 'Fan-tailed Widowbird',
#   'scientific_name': 'Euplectes axillaris',
#   'image_url': 'https://birda.twic.pics/species/4c9e8934-9ac6-4bde-810f-3adb8025f592/reference_images/Fan-tailed_Widowbird-_Male.jpg',
#   'guide_url': '/species-guide/32693/Fan-tailed_Widowbird'},
#  {'common_name': "Holub's Golden Weaver",
#   'scientific_name': 'Ploceus xanthops',
#   'image_url': 'https://birda.twic.pics/species/e02ad697-9672-4bbc-9800-fa4c3712b1dc/reference_images/Holubs_Golden_Warbler-_Male.jpg',
#   'guide_url': "/species-guide/32479/Holub's_Golden_Weaver"},
#  {'common_name': 'Lesser Masked Weaver',
#   'scientific_name': 'Ploceus intermedius',
#   'image_url': 'https://birda.twic.pics/species/e51b715d-0fac-4691-9798-9eb6e3e1f46e/reference_images/Lesser_Masked_Weaver-_Male.jpg',
#   'guide_url': '/species-guide/32498/Lesser_Masked_Weaver'},
#  {'common_name': 'Long-tailed Widowbird',
#   'scientific_name': 'Euplectes progne',
#   'image_url': 'https://birda.twic.pics/species/55306401-2b5e-4648-b6b9-820c1ed8b2df/reference_images/Long-tailed_Widowbird-_Male-_Breed.jpg',
#   'guide_url': '/species-guide/32721/Long-tailed_Widowbird'},
#  {'common_name': 'Olive-headed Weaver',
#   'scientific_name': 'Ploceus olivaceiceps',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32596/Olive-headed_Weaver'},
#  {'common_name': 'Red-billed Buffalo Weaver',
#   'scientific_name': 'Bubalornis niger',
#   'image_url': 'https://birda.twic.pics/species/77e14346-986c-4b81-a167-64ac7277fb5f/reference_images/Red-billed_Buffalo_Weaver-_Male.jpg',
#   'guide_url': '/species-guide/32392/Red-billed_Buffalo_Weaver'},
#  {'common_name': 'Red-billed Quelea',
#   'scientific_name': 'Quelea quelea',
#   'image_url': 'https://birda.twic.pics/species/fa7cd4ed-19e5-4f51-85e7-698525037736/reference_images/Red-billed_Quelea_-_Adult_Male_-_R.jpg',
#   'guide_url': '/species-guide/32640/Red-billed_Quelea'},
#  {'common_name': 'Red-collared Widowbird',
#   'scientific_name': 'Euplectes ardens',
#   'image_url': 'https://birda.twic.pics/species/9a0bc0cc-9f3c-4d91-a458-61c46ccb7d1e/reference_images/Red-collared_Widowbird-_Male.jpg',
#   'guide_url': '/species-guide/32715/Red-collared_Widowbird'},
#  {'common_name': 'Red-headed Quelea',
#   'scientific_name': 'Quelea erythrops',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32639/Red-headed_Quelea'},
#  {'common_name': 'Red-headed Weaver',
#   'scientific_name': 'Anaplectes rubriceps',
#   'image_url': 'https://birda.twic.pics/species/28b4bf42-ab45-47d0-8afb-a8b9730d6907/reference_images/Red-headed_Weaver-_Male.jpg',
#   'guide_url': '/species-guide/32630/Red-headed_Weaver'},
#  {'common_name': 'Scaly-feathered Weaver',
#   'scientific_name': 'Sporopipes squamifrons',
#   'image_url': 'https://birda.twic.pics/species/ad7b2ddf-711b-4999-9c34-a0f8a2e2ef71/reference_images/Scaley-feathered_Weaver.jpg',
#   'guide_url': '/species-guide/32419/Scaly-feathered_Weaver'},
#  {'common_name': 'Sociable Weaver',
#   'scientific_name': 'Philetairus socius',
#   'image_url': 'https://birda.twic.pics/species/b7fe783c-394f-433b-9bd5-4cb1758277ff/reference_images/Sociable_Weaver.jpg',
#   'guide_url': '/species-guide/32414/Sociable_Weaver'},
#  {'common_name': 'Southern Brown-throated Weaver',
#   'scientific_name': 'Ploceus xanthopterus',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32489/Southern_Brown-throated_Weaver'},
#  {'common_name': 'Southern Masked Weaver',
#   'scientific_name': 'Ploceus velatus',
#   'image_url': 'https://birda.twic.pics/species/e167a5bd-42d4-427a-9487-cd2a3346d302/reference_images/Southern_Masked_Weaver_-_Adult_Mal.jpg',
#   'guide_url': '/species-guide/32502/Southern_Masked_Weaver'},
#  {'common_name': 'Southern Red Bishop',
#   'scientific_name': 'Euplectes orix',
#   'image_url': 'https://birda.twic.pics/species/b90b93a4-daf0-4896-87ab-5192a6b43df6/reference_images/Southern_Red_Bishop_-_Adult_Male.jpg',
#   'guide_url': '/species-guide/32677/Southern_Red_Bishop'},
#  {'common_name': 'Spectacled Weaver',
#   'scientific_name': 'Ploceus ocularis',
#   'image_url': 'https://birda.twic.pics/species/2c857498-b2dc-4c9c-903f-19a134aebbb8/reference_images/Spectacled_Weaver_-_Adult.jpg',
#   'guide_url': '/species-guide/32456/Spectacled_Weaver'},
#  {'common_name': 'Thick-billed Weaver',
#   'scientific_name': 'Amblyospiza albifrons',
#   'image_url': 'https://birda.twic.pics/species/4f315460-fb50-4a2c-bbaf-ecb79e4b5e60/reference_images/Thick-billed_Weaver_-_Adult.jpg',
#   'guide_url': '/species-guide/32425/Thick-billed_Weaver'},
#  {'common_name': 'Village Weaver',
#   'scientific_name': 'Ploceus cucullatus',
#   'image_url': 'https://birda.twic.pics/species/f9f4be51-95b2-4471-9dc8-e109ab79837b/reference_images/Village_Weaver-_Male-_New.jpg',
#   'guide_url': '/species-guide/32522/Village_Weaver'},
#  {'common_name': 'White-browed Sparrow-Weaver',
#   'scientific_name': 'Plocepasser mahali',
#   'image_url': 'https://birda.twic.pics/species/b49c9d18-b042-4b00-91a5-4aee6cbc66d7/reference_images/White-browed_Sparrow-weaver-_Femal.jpg',
#   'guide_url': '/species-guide/32398/White-browed_Sparrow-Weaver'},
#  {'common_name': 'White-winged Widowbird',
#   'scientific_name': 'Euplectes albonotatus',
#   'image_url': 'https://birda.twic.pics/species/bb20bc3c-855a-4e31-8917-661da2dd1bc4/reference_images/White-winged_Widowbird-_Male.jpg',
#   'guide_url': '/species-guide/32710/White-winged_Widowbird'},
#  {'common_name': 'Yellow Bishop',
#   'scientific_name': 'Euplectes capensis',
#   'image_url': 'https://birda.twic.pics/species/b47d78e6-d4cb-483c-a9fc-99393667bdcb/reference_images/Yellow_Bishop-_Male.jpg',
#   'guide_url': '/species-guide/32685/Yellow_Bishop'},
#  {'common_name': 'Yellow-crowned Bishop',
#   'scientific_name': 'Euplectes afer',
#   'image_url': 'https://birda.twic.pics/species/bf955195-6a5d-471c-a316-92b51d8c2d9f/reference_images/Yellow-crowned_Bishop-_Male.jpg',
#   'guide_url': '/species-guide/32661/Yellow-crowned_Bishop'},
#  {'common_name': 'Yellow-mantled Widowbird',
#   'scientific_name': 'Euplectes macroura',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/32700/Yellow-mantled_Widowbird'},
#  {'common_name': 'Cape White-eye',
#   'scientific_name': 'Zosterops virens',
#   'image_url': 'https://birda.twic.pics/species/48d1fcb6-6f3c-47b5-97d4-5043f5cb0756/reference_images/Cape_White-eye.jpg',
#   'guide_url': '/species-guide/27085/Cape_White-eye'},
#  {'common_name': 'Northern Yellow White-eye',
#   'scientific_name': 'Zosterops senegalensis',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/27072/Northern_Yellow_White-eye'},
#  {'common_name': 'Orange River White-eye',
#   'scientific_name': 'Zosterops pallidus',
#   'image_url': 'https://birda.twic.pics/species/440ca57e-98ec-4f27-9d00-0225655ddc8a/reference_images/Orange_River_White-eye.jpg',
#   'guide_url': '/species-guide/27080/Orange_River_White-eye'},
#  {'common_name': 'Southern Yellow White-eye',
#   'scientific_name': 'Zosterops anderssoni',
#   'image_url': 'https://birda.twic.pics/species/82abc7b9-e582-42e2-ba6c-f005d20fa7e0/reference_images/Southern_Yellow_White-eye_.jpg',
#   'guide_url': '/species-guide/27091/Southern_Yellow_White-eye'},
#  {'common_name': 'Common Scimitarbill',
#   'scientific_name': 'Rhinopomastus cyanomelas',
#   'image_url': 'https://birda.twic.pics/species/2940b9d8-647b-4819-b4d4-b5c990f15d2a/reference_images/Common_Scimitarbill.jpg',
#   'guide_url': '/species-guide/9980/Common_Scimitarbill'},
#  {'common_name': 'Green Wood Hoopoe',
#   'scientific_name': 'Phoeniculus purpureus',
#   'image_url': 'https://birda.twic.pics/species/34b6bdb7-8b38-4459-b3b1-88c63e16b8e5/reference_images/Green_Wood_Hoopoe.jpg',
#   'guide_url': '/species-guide/9958/Green_Wood_Hoopoe'},
#  {'common_name': 'Violet Wood Hoopoe',
#   'scientific_name': 'Phoeniculus damarensis',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/9971/Violet_Wood_Hoopoe'},
#  {'common_name': 'Bearded Woodpecker',
#   'scientific_name': 'Chloropicus namaquus',
#   'image_url': 'https://birda.twic.pics/species/4701d8a7-8ce1-4a97-8805-9f2b21d4ea41/reference_images/Bearded_Woodpecker-_Male.jpg',
#   'guide_url': '/species-guide/11926/Bearded_Woodpecker'},
#  {'common_name': "Bennett's Woodpecker",
#   'scientific_name': 'Campethera bennettii',
#   'image_url': 'https://birda.twic.pics/species/67813663-ae39-4200-ae3f-d3e9b6969cca/reference_images/Bennetts_Woodpecker-_Male.jpg',
#   'guide_url': "/species-guide/11800/Bennett's_Woodpecker"},
#  {'common_name': 'Cardinal Woodpecker',
#   'scientific_name': 'Dendropicos fuscescens',
#   'image_url': 'https://birda.twic.pics/species/a6c6d27a-d3a8-4543-a784-c943fe3127c4/reference_images/Cardinal_Woodpecker-_Male.jpg',
#   'guide_url': '/species-guide/11937/Cardinal_Woodpecker'},
#  {'common_name': 'Golden-tailed Woodpecker',
#   'scientific_name': 'Campethera abingoni',
#   'image_url': 'https://birda.twic.pics/species/6536f91e-acc1-426b-bdde-919bb84cf424/reference_images/Golden-tailed_Woodpecker-_Female.jpg',
#   'guide_url': '/species-guide/11809/Golden-tailed_Woodpecker'},
#  {'common_name': 'Ground Woodpecker',
#   'scientific_name': 'Geocolaptes olivaceus',
#   'image_url': 'https://birda.twic.pics/species/468217ff-7e8a-4a1f-8f0c-825b96555c26/reference_images/Ground_Woodpecker.jpg',
#   'guide_url': '/species-guide/11793/Ground_Woodpecker'},
#  {'common_name': 'Knysna Woodpecker',
#   'scientific_name': 'Campethera notata',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/11821/Knysna_Woodpecker'},
#  {'common_name': 'Little Spotted Woodpecker',
#   'scientific_name': 'Campethera cailliautii',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/11822/Little_Spotted_Woodpecker'},
#  {'common_name': 'Olive Woodpecker',
#   'scientific_name': 'Dendropicos griseocephalus',
#   'image_url': 'https://birda.twic.pics/species/fe103628-67ff-49e4-94f1-da4fbdf2c829/reference_images/Olive_Woodpecker-_Male.jpg',
#   'guide_url': '/species-guide/11982/Olive_Woodpecker'},
#  {'common_name': 'Red-throated Wryneck',
#   'scientific_name': 'Jynx ruficollis',
#   'image_url': 'https://birda.twic.pics/species/8f928302-b1e6-4205-9a66-5ef43a22b64e/reference_images/Red-throated_Wryneck.jpg',
#   'guide_url': '/species-guide/11562/Red-throated_Wryneck'},
#  {'common_name': 'Speckle-throated Woodpecker',
#   'scientific_name': 'Campethera scriptoricauda',
#   'image_url': 'N/A',
#   'guide_url': '/species-guide/11804/Speckle-throated_Woodpecker'},
#  {'common_name': "Livingstone's Flycatcher",
#   'scientific_name': 'Erythrocercus livingstonei',
#   'image_url': 'N/A',
#   'guide_url': "/species-guide/25168/Livingstone's_Flycatcher"}]

# %%
len(birds)
# Out:
# 945

# %%
pages = [file for file in os.listdir('C:\\Users\\scuba\\Downloads\\BIRD APP\\bird-trainer\\BIRDA\\BIRDA PAGES') if file.endswith('.html')] 
pages
# Out:
# ['page_1.html',
#  'page_10.html',
#  'page_11.html',
#  'page_12.html',
#  'page_13.html',
#  'page_14.html',
#  'page_15.html',
#  'page_16.html',
#  'page_17.html',
#  'page_18.html',
#  'page_19.html',
#  'page_2.html',
#  'page_20.html',
#  'page_21.html',
#  'page_3.html',
#  'page_4.html',
#  'page_5.html',
#  'page_6.html',
#  'page_7.html',
#  'page_9.html']

# %%
# List of local HTML files to process 
pages = [file for file in os.listdir('C:\\Users\\scuba\\Downloads\\BIRD APP\\bird-trainer\\BIRDA\\BIRDA PAGES') if file.endswith('.html')] 

birds = []
# Get the directory where the script itself is located
script_dir = "C:\\Users\\scuba\\Downloads\\BIRD APP\\bird-trainer\\BIRDA\\BIRDA PAGES\\"

for n in range(1, len(pages)+2):
    page = f"page_{n}.html"
    # Join the script directory with the filename
    new_page = os.path.join(script_dir, page)
    # print(f"Checking: {new_page}")
    if os.path.exists(new_page):
        print(f"Processing {page}...")
# Out:
# Processing page_1.html...
# Processing page_2.html...
# Processing page_3.html...
# Processing page_4.html...
# Processing page_5.html...
# Processing page_6.html...
# Processing page_7.html...
# Processing page_9.html...
# Processing page_10.html...
# Processing page_11.html...
# Processing page_12.html...
# Processing page_13.html...
# Processing page_14.html...
# Processing page_15.html...
# Processing page_16.html...
# Processing page_17.html...
# Processing page_18.html...
# Processing page_19.html...
# Processing page_20.html...
# Processing page_21.html...

# %%
len(pages)
# Out:
# 20
